# %%
import pandas as pd
import numpy as np


d = pd.read_csv('mapping.csv', sep = ";")
d.head(3)
# Out:
#                   name  article
# 0  20220507_120534.jpg     4073
# 1  20220507_120537.jpg     4073
# 2  20220507_120540.jpg     4073

# %%
# d.article.value_counts()

# d.head(10)
# d.article.isnull().value_counts()



# list(d.article.unique())
# Out:
# 1

# %%
#делим наш датасет на обучающую и тестовую выборку

# (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle Boat']
# class_names

class_names_lego = list(d.article.sort_values().unique())
