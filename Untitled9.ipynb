# %%
myset3 = set('abcd')  
print(myset3)
print(len(myset3))
# Out:
# {'b', 'd', 'c', 'a'}
# 4

# %%
print(len(set('карабас-барабас')))
# Out:
# 6

# %%
a = 10

print(f'Число а = {a}')
# Out:
# Число а = 10

# %%
numbers = {9089, -67, -32, 1, 78, 23, -65, 99, 9089, 34, -32, 0, -67, 1, 11, 111, 111, 1, 23}

s = 0
for i in numbers:
    s = s + i**2
print(s)
# Out:
# 82649672

# %%
# Out:
# {'d', 'h', 'e', 'b', 'c', 'a', 'f', 'g'}
# d
# {'h', 'e', 'b', 'c', 'a', 'f', 'g'}
# h
# {'e', 'b', 'c', 'a', 'f', 'g'}
# e
# {'b', 'c', 'a', 'f', 'g'}
# b
# {'c', 'a', 'f', 'g'}
# c
# {'a', 'f', 'g'}
# a
# {'f', 'g'}
# f
# {'g'}

# %%
myset = set()
for i in range(10):
    if i % 2 == 0:
        myset.add('even')
    else:
        myset.add('odd')
print(len(myset))
# Out:
# 2

# %%
myset = set('python')

item = myset.pop()
print(item, len(myset))
# Out:
# p 5

# %%
myset = set()

item = myset.pop()
print(item)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-45862e0d03cc> in <module>()
#       1 myset = set()
#       2
# ----> 3 item = myset.pop()
#       4 print(item)
#
# KeyError: 'pop from an empty set'

# %%
#your code
s = [1, 2, 3, 4, 5.0, 6, 7, 8, 9, 10]
V1 = #your code
V2 = #your code
V3 = #your code
V4 = #your code
V5 = #your code

# %%
import numpy as np
a = np.array([1,2,3]) 
b = np.array([2,4,6]) 

b[b>=4]
# Out:
# array([4, 6])

# %%
import numpy as np
#np.arange(1,10,0.01)
np.linspace(1,10,20)
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
import numpy as np
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
col = "animal"
row = "e"
import pandas as pd
df = pd.DataFrame({'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
                   'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
                   'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
                   'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']},
                 index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

df['index' = 'e']
# Out:
#   File "<ipython-input-12-cedbd718b551>", line 10
#     df['index' = 'e']
#                ^
# SyntaxError: invalid syntax

# %%
f1 = lambda x,y: x+y
print(f1(2,4))
# Out:
# 6

# %%
print((lambda x,y: x+y)(1,5))
# Out:
# 6

# %%
any([True, True])
any([True, False])
# Out:
# True

# %%
print(all([True,  1]))
# Out:
# True

# %%
def square(x):
    return x**2


def cube(x):
    return x**3


numbers = [1, 2, -3, 4, -5, 6, -9, 0]

strings = map(str, numbers)        # используем в качестве преобразователя - функцию str
abs_numbers = map(abs, numbers)    # используем в качестве преобразователя - функцию abs

squares = map(square, numbers)     # используем в качестве преобразователя - функцию square
cubes = map(cube, numbers)         # используем в качестве преобразователя - функцию cube


#print(list(map(cubes, numbers)))
print(map(cubes, numbers))
# Out:
# <map object at 0x7fe745dd5850>
