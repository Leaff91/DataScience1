# %%
# import pandas as pd
# import numpy as np

# d = pd.read_csv('nests.csv', sep = ';')

# d.head()
# df = pd.DataFrame(d)

# df.head()


# df.groupby('Year')['Year'].count().plot(kind = 'pie')

df.groupby('Year').count()
# Out:
#       Nest  Vis  Age  Temp
# Year
# 2019     6    6    6     6
# 2020    20   20   20    20
# 2021    18   18   18    18

# %%
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    Year    Nest  Vis  Age  Temp
# 0  2019  HC1904  224   10  12.9
# 1  2019  HC1911  123    7  10.8
# 2  2019  HC1911  119    8  11.0
# 3  2019  HC1928  150    7   9.6
# 4  2019  HC1928  167    9  12.9

# %%
# df['Year'].value_counts(normalize = 'True')

#x = df
#x = df
#x.head()

#x.groupby('Year').mean().round(1)

# x.corr().round(1)

x.value_counts('Year').plot(kind = 'pie')

#.plot(kind = 'pie')

#x.isnull()

# %%
from pandas.plotting import scatter_matrix; 
scatter_matrix(df, alpha=0.5, figsize=(10, 10), diagonal="kde");
