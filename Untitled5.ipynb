# %%
a1=100
b1=200
n=10

a[0]=a1
a[n]=b1




for i in range(n):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3bb61704f76d> in <module>()
#       3 n=10
#       4
# ----> 5 a[0]=a1
#       6 a[n]=b1
#       7
#
# TypeError: 'int' object does not support item assignment

# %%
a-=5
a
# Out:
# -7

# %%
$$
y
$$
