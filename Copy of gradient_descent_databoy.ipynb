# %%
from numpy import asarray
from numpy import arange
from numpy.random import rand
import numpy as np
import matplotlib.pyplot as plt

# %%
def objective(x):
	return x**2.0

# %%
objective(10)
# Out:
# 100.0

# %%
bounds = np.array([[-10.0, 10.0]])

# %%
x = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
x
# Out:
# array([-3.90265157])

# %%
inputs = []
outputs = []

# %%
for i in range(1000):
  x = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
  y = objective(x)
  inputs.append(x)
  outputs.append(y)

# %%
plt.scatter(inputs, outputs)
# plot the solutions found
# plt.plot(solutions, scores, '.-', color='red')

# %%
x = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
x
# Out:
# array([5.03625858])

# %%
def derivative(x):
	return x * 2.0

# %%
derivative(x)
# Out:
# array([10.07251716])

# %%
# new_x = -8 - (-16) = 8
new_x = x - 0.1*derivative(x)
new_x
# Out:
# array([4.02900686])

# %%
x = new_x
new_x = x - 0.1*derivative(x)
new_x
# Out:
# array([3.22320549])

# %%
x = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
x
# Out:
# array([-2.81167466])

# %%
solutions = []
evaluations = []

# %%
for i in range(20):
  solutions.append(x)
  x_evaluation = objective(x)
  evaluations.append(x_evaluation)

  gradient = derivative(x)
  new_x = x - 0.1 * gradient
  x = new_x
  print('>%d f(%s) = %.5f' % (i, x, x_evaluation))
plt.scatter(inputs, outputs)
# plot the solutions found
plt.scatter(solutions, evaluations, color='red')
# Out:
# >0 f([-2.24933972]) = 7.90551
# >1 f([-1.79947178]) = 5.05953
# >2 f([-1.43957742]) = 3.23810
# >3 f([-1.15166194]) = 2.07238
# >4 f([-0.92132955]) = 1.32633
# >5 f([-0.73706364]) = 0.84885
# >6 f([-0.58965091]) = 0.54326
# >7 f([-0.47172073]) = 0.34769
# >8 f([-0.37737658]) = 0.22252
# >9 f([-0.30190127]) = 0.14241
# >10 f([-0.24152101]) = 0.09114
# >11 f([-0.19321681]) = 0.05833
# >12 f([-0.15457345]) = 0.03733
# >13 f([-0.12365876]) = 0.02389
# >14 f([-0.09892701]) = 0.01529
# >15 f([-0.07914161]) = 0.00979
# >16 f([-0.06331328]) = 0.00626
# >17 f([-0.05065063]) = 0.00401
# >18 f([-0.0405205]) = 0.00257
# >19 f([-0.0324164]) = 0.00164
