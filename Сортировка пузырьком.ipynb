# %%
n = 4
mas = [1,4,5,2]
count = 0 

for j in range(n-1):
  for i in range(n-1-j):
      if mas[i]>mas[i+1]:
        mas[i],mas[i+1] = mas[i+1],mas[i]
        count +=1
  print(mas)
# Out:
# [1, 4, 2, 5]
# [1, 2, 4, 5]
# [1, 2, 4, 5]

# %%
# Out:
# [2, 3, 4, 5, 7, 8]
# [2, 3, 4, 5, 7, 8]
# [2, 3, 4, 5, 7, 8]
# [2, 3, 4, 5, 7, 8]
# [2, 3, 4, 5, 7, 8]
