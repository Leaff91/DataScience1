# %%
import pandas as pd
import numpy as np

# %%
a=10
print(f'asdfasdf {a}, {a**2}')
# Out:
# asdfasdf 10, 100

# %%
l = lambda x: x**2 
print(l(5))
# Out:
# 25

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jorisvandenbossche/pandas-tutorial/master/data/titanic.csv')

# %%
# df.columns()

# df.head()


# ser1 = pd.Series([1,1,2,3,7], index = [1,2,3,4,5])
# ser1 = pd.Series([1, 1, 2, 3, 7])

#df.columns=['c1', 'c2',  'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12']
df.columns
# Out:
# Index(['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11',
#        'c12'],
#       dtype='object')

# %%
df[['Age', 'Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# df.columns[1]

# cond = df['Age'].isin([17,18])
# df[cond]
# df.sort_values('PassengerId', ascending = True)

# объединение по строкам:
# df2 = pd.concat([df,df])
# df2.shape


# объединение по столбцам:
# df3 = pd.concat([df,df], axis = 1)
# df3.shape
df3.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#   Parch            Ticket     Fare  ... Pclass  \
# 0     0         A/5 21171   7.2500  ...      3
# 1     0          PC 17599  71.2833  ...      1
# 2     0  STON/O2. 3101282   7.9250  ...      3
# 3     0            113803  53.1000  ...      1
# 4     0            373450   8.0500  ...      3
#
# ...

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# df.groupby(['Sex'])['Age'].mean().round(1)
# df.columns[1]

c  = df.columns[1] 

df.groupby(c)['Age'].agg(['mean', 'median', 'sum' , 'count']).round(1)

df.corr().round(2)
# Out:
#              PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00     -0.01   -0.04  0.04  -0.06  -0.00  0.01
# Survived           -0.01      1.00   -0.34 -0.08  -0.04   0.08  0.26
# Pclass             -0.04     -0.34    1.00 -0.37   0.08   0.02 -0.55
# Age                 0.04     -0.08   -0.37  1.00  -0.31  -0.19  0.10
# SibSp              -0.06     -0.04    0.08 -0.31   1.00   0.41  0.16
# Parch              -0.00      0.08    0.02 -0.19   0.41   1.00  0.22
# Fare                0.01      0.26   -0.55  0.10   0.16   0.22  1.00

# %%
# df['Age'].plot(kind = 'hist', xlim = [0,100], ylim = [0,200], )

# The kind of plot to produce:

# 'hist' : histogram
# 'kde' : Kernel Density Estimation plot
# 'density' : same as 'kde'

# 'line' : line plot (default)
# 'bar' : vertical bar plot
# 'area' : area plot


# 'barh' : horizontal bar plot

# 'box' : boxplot

# 'pie' : pie plot
# 'scatter' : scatter plot (DataFrame only)
# 'hexbin' : hexbin plot (DataFrame only)
# ax : matplotlib axes object, default None

# df['Age'].plot(kind = 'kde', legend = 'True')

df.groupby(['Sex'])['Age'].plot(kind = 'kde', legend = 'True')
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
# tmp_df = df.copy(deep=True)

# tmp_df['is18'] = tmp_df['Age'] >=18
# tmp_df.sort_values('Survived').head(10)
ff = tmp_df.rename(columns={'PassengerId': 'Id'})

ff.head()
# Out:
#    Id  Survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  is18
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S  True
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C  True
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  True
# 3  female  35.0      1      0            113803  53.1000  C123        S  True
# 4    male  35.0      0      0            373450   8.0500   NaN        S  True

# %%
# %%time

s=0
for i  in range(1,1000):
    s=s+i
print(s)
# Out:
# 499500
# CPU times: user 594 µs, sys: 0 ns, total: 594 µs
# Wall time: 537 µs
