# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера</h1>
#
# Привет, Анастасия!
#
# Меня зовут Усов Егор, и я буду проверять твой проект) Предлагаю нам сразу перейти на ты, если ты не против)
#
# Основная моя задача помочь тебе в освоении пройденного материала, а не в оценке проекта, поэтому не стесняйся задавать вопросы, если они есть)
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>✅зелёный</font> - всё сделано правильно; <font color=orange>⚠️оранжевый</font> - есть что улучшить, но не критично; <font color=red>красный</font> и есть такой ❌ знак- нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
#
# Ты можешь отвечать мне своими комментариями и выделять их другим <font color=blue>цветом</font>.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# **Комментарий студента**
#
# Для примера)

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Общий комментарий </h1>
#
# Проект сыроват. В целом видно, что выполнение заданий не вызывает у тебя затруднений. Все рассчеты выполнены верно, ты умело применяешь доступные инструменты. Но аналитическая работа это не только расчеты, но и презентация результатов. Читать проект без структуры довольно сложно.
#
# Есть замечания, которые нужно устранить, прежде чем я приму твою работу.
#
# Что нужно поправить:
# - пояснить почему заполнение пропусков в числовых колонках средним значением допустимо. Какую долю у нас составляют пропуски в этих колонках? При какой доле есть смысл что-то заполнять?
# - пояснить применение целочисленного типа ко всем числовым колонкам.
# - нужно добавить расчеты, по которым можно сделать вывод о выборе актуальных платформ.
# - нужно построить график боксплот без выбросов.
# - при определении самого прибыльного жанра нужно воспользоваться средними или медианными продажами.
# - после оценки коэффициентов корреляции между продажами и оценками добавить вывод.
# - проверить вывод о корреляции на остальных платформах.
# - при построении портретов пользователей учесть игры без рейтинга ESRB.
# - по результатам построения портретов добавить вывод.
# - добавить вывод по результатам проверки гипотез.
# - добавить общий вывод.
# - сформировать структуру проекта, отделить шаги заголовками (обзор, предобработка, анализ, портреты, гипотезы). Каждый шаг завершить коротким выводом.
#
# Крайне желательно оформить построенные графики.
#
# Жду твою работу на повторную проверку.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Общий комментарий V2</h1>
#
# Спасибо за твои доработки.
#
# Тебе удалось устранить многое, но кое-что еще нужно исправить.
#
# Что нужно поправить:
# - поменять типы ячеек, в которых ты пишешь комментарии на markdown.
# - проверить код, не все ячейки работают.
# - нужно добавить таблицу или график, на которых будет видно, что топовые платформы еще не прошли свой пик продаж.
# - нужно добавить вывод после определения самого прибыльного жанра.
# - при построении портретов пользователей учесть игры без рейтинга ESBR.
# - при проведении статистических тестов отфильтровать данные от пропусков и проверить выводы после расчетов.
#
#
# Жду твой проект на следующую итерацию проверки. Если у тебя есть вопросы, не стесняйся из задавать. Если у тебя есть сложности в решении, каких-то заданий ты можешь обратиться к преподавателю по проектам в канале в слаке.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера💡</h1>
#
# Неплохо бы сделать небольшое вступление к проекту. Набросать план предстоящей работы.
#
# </div>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# df = pd.read_csv('/datasets/games.csv') 
df = pd.read_csv('games.csv')

# %%
# print(df.head())
df.head()
# df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-9e28fe01bdaf> in <module>
# ----> 1 df.rating.notna()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rating'

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера💡</h1>
#
# Лучше разделять импорт библиотек и загрузку данных в разные ячейки, чтобы не перезагружать данные, когда нужно будет добавить новую библиотеку.
# ok
# </div>

# %%
#Преобразуем названия столбцов в нижний регистр
# df.columns = df.columns.str.strip().str.lower()

df.columns = df.columns.str.strip().str.lower()


# df.columns

df.head(3)
# Out:
# 16715

# %%
df.rating.count()



df["rating"] = df["rating"].fillna("unknown")

df["rating"].head(8)
# Out:
# 0          E
# 1    unknown
# 2          E
# 3          E
# 4    unknown
# 5    unknown
# 6          E
# 7          E
# Name: rating, dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера✅</h1>
#
# Отлично.
#
# </div>

# %%
#Преобразуем форматы и заполняем средним

df.loc[df['user_score'] == 'tbd', 'user_score'] = np.nan


df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
# Преобразуем строки в столбцах critic_score и user_score во float'ы
score_columns = ['critic_score', 'user_score']
df[score_columns] = df[score_columns].astype(float)
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %%
# Округлим значения до десятых в столбце user_score
df['user_score'] = df['user_score'].round(1)

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Ячейка на запускается. Нужно поправить код. ok
#
# Старайся перед отправкой работы на проверку выполнять полный перезапуск всех ячеек, чтобы убедится, что все работает как надо.
#
# Можно нажать вот эту кнопку:
#
# ![image.png](attachment:image.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# Почему ты считаешь, что заменить пропуски на среднее значение, это корректное решение?
#
# И типы даннх, разве везде должны быть целые числа?
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера V2💡</h1>
#
# Я так понял, что ты решила не заполнять пропуски средним значением. Если ты решила оставить данные как есть, об этом тоже следует написать небольшой комментарий.
#
# </div>

# %% [markdown]
# Поработаем со столбцом rating:
#
# Заменим рейтинг K-A на E, поскольку это один и тот же рейтинг, но в разные периоды он назывался по-разному: K-A в 1994-1998, E с 1998 по настоящее время
# В столбце rating также есть nan'ы и это тоже достаточно легко объяснимо:
#
# некоторые из игр, не имеющие ESRB-рейтинга, вышли до начала деятельности одноименной организации
# многие из игр попросту не были оценены организацией ESRB
# Заполнять эти пропуски, пытаясь предугадать результат, не стоит, поскольку в дальнейшем нам понадобится делать выборки по ESRB-рейтингу и, в конечном итоге, это может привести к неточностям в результатах, а следовательно, и в выводах
#
# Есть достаточно точный автоматический способ - собирать данные с сайта esrb.com, но это будет крайне медленная операция, поскольку поиск на этом сайте реализован достаточно неудобным образом - придется находить "похожесть" названия игры с каждым результатом поиска
#
# Можно вспомнить про рейтинг RP (rating pending), но он используется исключительно в рекламных материалах игр, которым еще не был присвоен окончательный рейтинг

# %%
# Заменим все K-A в столбце rating на E, поскольку это один рейтинг,
# но в разные периоды он назывался по-разному
df.loc[df['rating'] == 'K-A', 'rating'] = 'E'

df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Код не работает. Нужно поправть. ok
#
# </div>

# %%
#Удалим 2 пропуска 
df = df[df['name'].notna()]
df = df[df['genre'].notna()]
print(df.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating             6764
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера✅</h1>
#
# Две записи можно без пробем удалить.
#
# </div>

# %% [markdown]
# Удалила пропуски в столбцах - 'Name', 'Genre' - их по мало и не повлияют на результаты. В столбцах Year_of_Release, Critic_Score, User_Score, Rating - заполнила средним. Возможно пропуски возникли при заполенении, а в столбцах с оценками и рейтингом не всем играм их присваивали.

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера V2💡</h1>
#
# Вот наверно в этом комментарии нужно уточнить, как именно ты решила поступить с пропусками.
#
# </div>

# %%
# Посчитаем столбец со всеми продажами
df['total_sales'] = (
    df['na_sales']
    + df['eu_sales']
    + df['jp_sales']
    + df['other_sales']
)

df['total_sales'].head()
# Out:
# 0    82.54
# 1    40.24
# 2    35.52
# 3    32.77
# 4    31.38
# Name: total_sales, dtype: float64

# %%
df.head()
# print(df.head())
# display(df.head())
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера💡</h1>
#
# Выводить на экран таблицы функцией print не принято. Следует использовать функцию display.
#
# </div>

# %% [markdown]
# Рассмотрим, сколько игр выпускалось в различные годы
#
# Как следует из полученного графика, популярность видеоигр возрастала с 1990 года, а основной пик пришелся на 2008-2009 года - через несколько лет после появления удобных игровых движков вроде CryENGINE, Source, Unity, Unreal Engine и других, после чего последовал спад, т.к. приблизительно с 2011-2012 года требования игроков к играм значительно возрасли, как и масштабы самих игр - теперь на разработку компаниям приходилось затрачивать значительно больше времени и ресурсов

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Комментарии к работе следует оставлять в ячейках markdown. Чтобы поменять тип ячейки нужно ее выделить и выбрать нужное значение в выпадающем списке. ok
#
# ![image.png](attachment:image.png)
#
#
# </div>

# %% [markdown]
# Посмотрим, сколько игр выпускалось в разные годы.

# %%
plt.figure(figsize=(15, 5))
df.groupby('year_of_release').size().plot(kind='bar', title = 'Количество игр, выпускаемое в разные годы', xlabel='Год релиза', ylabel='Количество игр')

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера💡</h1>
#
# График верный, но нужно добавить название и подписи к осям. ок
#
# </div>

# %% [markdown]
# Данных до 1994 мало, можно сказать, что они неважны

# %% [markdown]
# Выберем 5 наиболее популярных платформ (у которых наибольшие продажи игр), и построим графики продаж по годам, чтобы посмотреть как менялись продажи для каждой из этих платформ

# %% [markdown]
# Посмотрим, как менялись продажи по платформам.
# Выберем платформы с наибольшими суммарными продажами и построим распределение по годам.

# %%
groups = df.groupby(['platform', 'year_of_release'])['total_sales'].sum().unstack('platform')
top5_platforms = list(groups.sum().nlargest(5).index)

fig, axes = plt.subplots(ncols=5, sharey='all', sharex='all', figsize=(14, 4))
for platform, ax in zip(top5_platforms, axes.flatten()):
    groups[platform].plot(xlabel="Year", ax=ax, title = platform, xlim = (2000, 2020))
fig.tight_layout()

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера💡</h1>
#
# Круто, что ты используешь subplots. Но графики тоже стоит оформить. ok
#
# </div>

# %% [markdown]
# На основании 5 прибыльнейших платформ можно сделать следующие выводы:
# В среднем платформа пользуется спросом в течение ~10 лет
# В среднем пик продаж игр на платформу приходится на 4-5 год ее существования

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера✅</h1>
#
# Похоже, что так.
#
# </div>

# %% [markdown]
# Возьмем данные за соответствующий актуальный период.
# Актуальный период определим самостоятельно в результате исследования предыдущих вопросов.
# Основной фактор — эти данные помогут построить прогноз на 2017 год.

# %%
actual_games = df[df['year_of_release'] >= 2013]
actual_games.head()



df[df['platform']== 'PS4'].groupby('year_of_release')['total_sales'].sum().sort_values()

.plot(title = 'PS4')

df[df['platform']== 'PS4'].groupby('year_of_release')['total_sales'].sum().plot()

df[df['platform']== 'PS4'].groupby('year_of_release')['total_sales'].sum().plot(xlabel = 'Year', xlim = (2013, 2016), ylabel ='total_sales')


# df[df['platform']== 'PS4'].groupby('year_of_release')['total_sales'].sum().plot(title = 'PS4')


# df[df['platform']== 'PS4'].groupby('year_of_release')['total_sales'].sum().plot(xlabel = 'Year', title = 'PS4', ylabel ='total_sales')
# Out:
#   File "<ipython-input-17-02decad7df39>", line 8
#     .plot(title = 'PS4')
#     ^
# SyntaxError: invalid syntax

# %%
df.groupby('platform')['total_sales'].sum().sort_values(ascending=False).head().round(1)

# %%
# df[df['platform']== 'XOne'].groupby('year_of_release')['total_sales'].sum().plot(xlabel = 'Year', xlim = (2013, 2016), title = 'XOne', ylabel ='total_sales')

df[df['platform']== 'XOne'].groupby('year_of_release')['total_sales'].sum().plot(xlabel = 'Year', xlim = (2013, 2016), ylabel ='total_sales')

# %% [markdown]
# Новейшие из консолей, представленные в датасете:
# - Xbox One         (2013)
# - PlayStation 4    (2013)
#
# Можно предположить, что пик продаж этих консолей придется на 2017-2018 года,
# поскольку это две наиболее популярные линейки домашних консолей
#
# Поэтому будет разумно выбрать в качестве актуального периода 2013-2016 года

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# Платформы ты отобрала верно. Но нужно вывести на экран, расчеты на основании которых ты это сделала.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Нужно добавить таблицу или график, которые бы показали, что продажи на этих платформах действительно растут. Хорошо, что ты используешь дополнительные источники информации, но все же нам нужно убедится, что именно на этих платформах пик продаж еще не прошел. ok
#
# </div>

# %% [markdown]
# Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам.

# %%
sales_by_platform = actual_games.groupby('platform')

fig, axes = plt.subplots(nrows=2, ncols=6, figsize=(14,10))
for (platform, ax) in zip(sales_by_platform.groups.keys(), axes.flatten()):
    sales_by_platform.get_group(platform)['total_sales'].plot(kind='box', ax=ax, ylim = (0,16), title = platform)
fig.tight_layout()

# %% [markdown]
# Теперь удалим выбросы и снова отобразим графики:

# %%
sales_by_platform = actual_games.groupby('platform')

fig, axes = plt.subplots(nrows=2, ncols=6, figsize=(14,10))
for (platform, ax) in zip(sales_by_platform.groups.keys(), axes.flatten()):
    total_sales = sales_by_platform.get_group(platform)['total_sales']
    q1 = total_sales.quantile(.25)
    q3 = total_sales.quantile(.75)
    total_sales = total_sales[total_sales.between(q1, q3)]
    total_sales.plot(kind='box', ax=ax, ylim = (0,0.8), title = platform)
fig.tight_layout()

# %% [markdown]
# **Вывод**
# Более высокие медианные продажи наблюдаются для PS4 и XOne

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# Для некоторых платформ мы видим только выбросы и совсем не видны квантили и медиана. Нужно построить второй график, на котором будут отброшены выбросы.
#
# В идеале построить график на одной фигуре, чтобы ось Y была одна и сравнивать платформы между собой было бы удобнее. ok
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# График построили. Теперь его нужно проинтерпретировать. Можно например отметить, для каких платформ у нас наблюдаются более высокие медианные продажи. ok
#
# </div>

# %% [markdown]
# Посмотрим на общее распределение игр по жанрам, построив для этого графики количества игр в каждом жанре, а также медианных продаж для каждого из жанров

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Нужно поменять тип ячейки на маркдаун. ok
#
# </div>

# %%
games_by_genre = actual_games.groupby('genre')
games_in_genres_count = games_by_genre.size().sort_values()
games_in_genres_median_sales = games_by_genre['total_sales'].median().sort_values()
games_in_genres_mean_sales = games_by_genre['total_sales'].mean().sort_values()

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(22,4), sharey=False)
axes[0].set_xlabel('Количество игр в жанре')
axes[1].set_xlabel('Медианные продажи игр по жанрам')
axes[2].set_xlabel('Cредние продажи игр по жанрам')
games_in_genres_count.plot(kind='barh', ax=axes[0])
games_in_genres_median_sales.plot(kind='barh', ax=axes[1])
games_in_genres_mean_sales.plot(kind='barh', ax=axes[2])
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Отлично. Построили график медианных продаж. Осталось теперь отобрать самый потенциально прибыльный жанр.
#
# </div>

# %% [markdown]
# Рассмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Для этого построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Нужно поменять тип ячейки.
#
# </div>

# %% [markdown]
# Самый прибыльный жанр игр - Action, наименение прибыльный - Puzzle
#
# Наиболее популярной платформой является PlayStation 4, поэтому возьмем ее за основу

# %%
ps4_actual_games = actual_games[actual_games['platform'] == 'PS4']
ps4_actual_scores_and_sales = ps4_actual_games.loc[:, ['total_sales', 'critic_score', 'user_score']]

# %% [markdown]
# Покажем корреляцию между оценками критиков, игроков и продажами

# %%
print(ps4_actual_scores_and_sales.corr().round(2))

# %% [markdown]
# Покажем диаграмму рассеяния

# %%
pd.plotting.scatter_matrix(ps4_actual_scores_and_sales, figsize=(10, 10))
plt.show()

# %% [markdown]
# **Вывод:**
#
# Как видно из графика, продажи зависят от оценок критиков (чем выше оценка, тем больше продаж), но не зависит от оценок пользователей. К тому же, есть корреляция между оценками критиков и игроков, чем выше оценка критиков, тем выше оценка игроков
#
# Теперь посмотрим, применимы ли сделанные выводы к нескольким другим платформам.
#
# Возьмем платформы из одинаковых поколений и ПК:
#
# PlayStation 4 и Xbox One
# PlayStation 3 и Xbox 360
# ПК

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера V2💡</h1>
#
# Верно. Есть небольшая зависимость оценок критиков и продаж. А влияние оценок игроков отсутствует.
#
# Только нужно поменять тип ячейки. ok
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера💡</h1>
#
# Вот это действие мне кажется лучше перенести в начало, где проводится предобработка.
#
# </div>

# %%
# Xbox One
xone_actual_games = actual_games[actual_games['platform'] == 'XOne']
xone_actual_scores_and_sales = xone_actual_games.loc[:, ['total_sales', 'critic_score', 'user_score']]

# Покажем корреляцию между оценками критиков, игроков и продажами
print(xone_actual_scores_and_sales.corr().round(2))

# Покажем диаграмму рассеяния
pd.plotting.scatter_matrix(xone_actual_scores_and_sales, figsize=(10, 10))
plt.show()

# %%
# PlayStation 3
ps3_actual_games = actual_games[actual_games['platform'] == 'PS3']
ps3_actual_scores_and_sales = xone_actual_games.loc[:, ['total_sales', 'critic_score', 'user_score']]

# Покажем корреляцию между оценками критиков, игроков и продажами
print(ps3_actual_scores_and_sales.corr().round(2))

# Покажем диаграмму рассеяния
pd.plotting.scatter_matrix(ps3_actual_scores_and_sales, figsize=(10, 10))
plt.show()

# %%
# Xbox 360
x360_actual_games = actual_games[actual_games['platform'] == 'X360']
x360_actual_scores_and_sales = x360_actual_games.loc[:, ['total_sales', 'critic_score', 'user_score']]

# Покажем корреляцию между оценками критиков, игроков и продажами
print(x360_actual_scores_and_sales.corr().round(2))

# Покажем диаграмму рассеяния
pd.plotting.scatter_matrix(x360_actual_scores_and_sales, figsize=(10, 10))
plt.show()

# %%
# PC
pc_actual_games = actual_games[actual_games['platform'] == 'PC']
pc_actual_scores_and_sales = pc_actual_games.loc[:, ['total_sales', 'critic_score', 'user_score']]

# Покажем корреляцию между оценками критиков, игроков и продажами
print(pc_actual_scores_and_sales.corr().round(2))

# Покажем диаграмму рассеяния
pd.plotting.scatter_matrix(pc_actual_scores_and_sales, figsize=(10, 10))
plt.show()

# %% [markdown]
# **Вывод:**
# В целом, ситуация на других платформах похожа на ситуацию с PlayStation 4

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера V2💡</h1>
#
# Согласен. Ситуация на других платформах таже самая.
#
# Не забудь, пожалуйста поменять тип ячейки. ok
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# График построили, коэффициенты рассчитали,  не хватает вывода.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# После формулирования вывода, по заданию нам нужно проверить его актуальность для других платформ.
#
# </div>

# %% [markdown]
# Определим для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5).

# %%
actual_games_by_platform = actual_games.groupby('platform')
columns = ['na_sales', 'eu_sales', 'jp_sales']
country_by_column = {
    'na_sales': 'Северной Америке',
    'eu_sales': 'Европе',
    'jp_sales': 'Японии'
}
for column in columns:
    print(f'Топ 5 популярных платформ в {country_by_column[column]}:')
    top5_platforms = actual_games_by_platform[column].sum().nlargest(5)
    for platform, sales in top5_platforms.items():
        print(f'{platform} - {sales:.1f} млн. долларов, {sales/top5_platforms.sum()*100:.1f} %')
    print()

# %% [markdown]
# Доли PS4 - 28% в Северной Америке, 42% в Европе, 12% в Японии.
# Доли XOne - 24% в Северной Америке, 15% в Европе.
# Доли X360 - 21% в Северной Америке, 13% в Европе.
# Доли PS3 - 16% в Северной Америке, 20% в Европе, 17% в Японии.
# Доли 3DS - 10% в Северной Америке, 9% в Европе, 50% в Японии.
# Доли PSV - 14% в в Японии, WiiU - 8% в в Японии.

# %% [markdown]
# **Вывод:**
#
# PlayStation и Xbox - давние конкуренты на рынке США, поэтому там платформы этих компаний имеют достаточно схожие продажи в рамках одного поколения консолей
#
# В Европе несколько иная ситуация - Xbox всегда был нацелен на американскую аудиторию, поэтому некоторые функции были доступны только для них, а в купе с общей политикой компании - становится все еще печальнее. Так, при старте продаж Xbox One, во многих странах Европейского союза эта консоль вовсе не была доступна
#
# Популярность Nintendo 3DS в Японии обуславливает не только то, что Nintendo - местный производитель, но и то, что на рынке Японии крайне популярны портативные консоли, в которые помимо Nintendo 3DS входит и PlayStation Vita

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера V2💡</h1>
#
# Хороший вывод. Но нужно поменять тип ячейки. ok
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера💡</h1>
#
# Топ 5 определен. В целом задание выполнено верно. Но мне кажется, стоит добавить расчет процентов, которые ты используешь в выводе, чтобы вывод не казался убедительнее. ok
#
# </div>

# %% [markdown]
# Определим для пользователя каждого региона (NA, EU, JP):
#  Самые популярные жанры (топ-5).

# %%
actual_games_by_genre = actual_games.groupby('genre')

for column in columns:
    print(f'Топ 5 популярных жанров в {country_by_column[column]}:')
    top5_genres = actual_games_by_genre[column].sum().nlargest(5)
    for genre, sales in top5_genres.items():
        print(f'{genre} - {sales:.1f} млн. долларов, {sales/top5_genres.sum()*100:.1f} %')
    print()

# %% [markdown]
# __Вывод:__
#
# В целом, рынки Северной Америки и Европы достаточно сильно похожи, чего не скажешь
# о Японии
#
# В Японии преобладает жанр RPG, поскольку это тот жанр, который является
# знаковым во всей японской игровой индустрии, существует даже отдельный жанр для
# местных RPG - jRPG (Japan RPG)
#
# Также стоит отметить, что в Японии игроки отдают предпочтение играм, в которых
# имеется глубокий сюжет и развитая история окружающего мира, в то время как
# американские и европейские игроки отдают предпочтение сессионным играм, когда
# можно уделить игре небольшой промежуток времени, достигнув при этом логического
# завершения партии

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера V2💡</h1>
#
# Здорово. Очень интересное замечание насчет японских РПГ.
#
# Поменяй, пожалуйста, тип ячейки.
#
# </div>

# %% [markdown]
# Определим для пользователя каждого региона (NA, EU, JP):
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
actual_games_by_rating = actual_games.groupby('rating')

for column in columns:
    print(f'Продажи по ESRB рейтингу в {country_by_column[column]}:')
    genre_sales = actual_games_by_rating[column].sum().sort_values(ascending=False)
    for rating, sales in genre_sales.items():
        print(f'{rating} - {sales:.2f} млн. долларов')
    print()

# %% [markdown]
# **Вывод:**
#
# Ключевое различие рынков в том, что японский рынок нацелен на условно детские игры, потому как в этом регионе наиболее распространены портативные консоли, которыми чаще всего пользуются именно дети

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Неплохой вывод.
#
# Осталось учесть в анализе игры без рейтинга ESRB. Заполни, пожалуйста пропуски в этой колонке значением по умолчанию - например "no_rating" и посмотри на результаты группировки еще раз. Возможно картина поменяется.
#
# </div>

# %%
actual_games_r = df[(df['year_of_release'] >= 2013) & (df.rating.notna())]


actual_games_by_rating = actual_games_r.groupby('rating')

for column in columns:
    print(f'Продажи по ESRB рейтингу в {country_by_column[column]}:')
    genre_sales = actual_games_by_rating[column].sum().sort_values(ascending=False)
    for rating, sales in genre_sales.items():
        print(f'{rating} - {sales:.2f} млн. долларов')
    print()

# %%
df

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах.
#
# Попробуй заменить пропуски в столбце с рейтингом на значение по умолчанию и проверь, как это повлияет на результат.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# По результатам построения портртетов пользователей нужно добавить вывод.
#
# </div>

# %% [markdown]
# Проверим гипотезу: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# Ее можно формализовать в таком виде:
#
# Нулевая гипотеза: Средние пользовательские рейтинги Xbox One = средние пользовательские рейтинги PC
#
# Альтернативная гипотеза: Средние пользовательские рейтинги Xbox One ≠ средние пользовательские рейтинги PC
#
# Для оценки гипотезы будем использовать тест Стьюдента

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Комментарий ревьюера V2💡</h1>
#
# Гипотезы сформулированы верно.
#
# Поменяй пожалуйста тип ячейки.
#
# </div>

# %% [markdown]
# Проверим гипотезы
#
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# H_0: Средние пользовательские рейтинги Xbox One = средние пользовательские рейтинги PC
# H_а: Средние пользовательские рейтинги Xbox One ≠ средние пользовательские рейтинги PC

# %%
pc_actual_games_user_scores = actual_games_by_platform['user_score'].get_group('PC')
xo_actual_games_user_scores = actual_games_by_platform['user_score'].get_group('XOne')



pc_actual_games_user_scores = pc_actual_games_user_scores[pc_actual_games_user_scores.notna()]
xo_actual_games_user_scores = xo_actual_games_user_scores[xo_actual_games_user_scores.notna()]



results = stats.ttest_ind(
    pc_actual_games_user_scores, 
    xo_actual_games_user_scores, 
    equal_var=False
)
alpha = 0.05

print('p-value:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Перед проведением статистического теста нам нужно удалить пропущенные значения в колонке с оценками. Тест работает некорректно при наличии пропусков. Можно это наблюдать по значению p-value - оно у нас неопределено.
#
# Отфильтруй, пожалуйста, дополнительно наши выборки от пропущенных значений и посмотри на резултат еще раз. ok
#
# </div>

# %% [markdown]
# **Вывод:**
#
# Т.к. не удалось отвергнуть нулевую гипотезу, значит гипотеза была верна - средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# Проверим гипотезу: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Ее можно формализовать в таком виде:
#
# Нулевая гипотеза: Средние пользовательские рейтинги Action = средние пользовательские рейтинги Sports
#
# Альтернативная гипотеза: Средние пользовательские рейтинги Action ≠ средние пользовательские рейтинги Sports
#
# Для оценки гипотезы будем использовать тест Стьюдента

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера✅</h1>
#
# Гипотезы сформулированы верно.
#
# Хорошо бы вывести сами рейтинги на экран.
#
# </div>

# %% [markdown]
#  Проверим гипотезы
#  Средние пользовательские рейтинги жанров
# Action (англ. «действие», экшен-игры) и
# Sports (англ. «спортивные соревнования») разные.
#
# H_0: Средние пользовательские рейтинги Action = средние пользовательские рейтинги Sports
# H_a: Средние пользовательские рейтинги Action ≠ средние пользовательские рейтинги Sports

# %%
action_actual_games_user_scores = actual_games_by_genre['user_score'].get_group('Action')
sports_actual_games_user_scores = actual_games_by_genre['user_score'].get_group('Sports')


action_actual_games_user_scores = action_actual_games_user_scores[action_actual_games_user_scores.notna()]
sports_actual_games_user_scores = sports_actual_games_user_scores[sports_actual_games_user_scores.notna()]

results = stats.ttest_ind(
    action_actual_games_user_scores, 
    sports_actual_games_user_scores, 
    equal_var=False
)
alpha = 0.05

print('p-value:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Тут тоже унжно отфильтровать пропуски перед проведением теста. ok
#
# </div>

# %% [markdown]
# Вывод:
#
# Т.к. отвергли нулевую гипотезу, значит наша гипотеза была верна - средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# Общий вывод:В проекте рассчитаны общие продажи во всех регионах, заменили tbd на nan,  преобразованы столбцы в тип данных float, округлены значения до десятых в столбце user_score, в столбце rating заменены рейтинг K-A на E, рассмотрено сколько игр выпускалось в различные годы, выбраны 5 наиболее популярных платформ (у которых наибольшие продажи игр) и рассмотрено как менялись продажи для каждой из этих платформ, выбран актуальный период для построения прогноза на 2017 год, рассмотрено общее распределение игр по жанрам, рассмотрено как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков
#
# В среднем платформа пользуется спросом в течение ~7 лет
# В среднем пик продаж игр на платформу приходится на 4-5 год ее существования
# Продажи зависят от оценок критиков (чем выше оценка, тем больше продаж), но не зависит от оценок пользователей. К тому же, есть корреляция между оценками критиков и игроков, чем выше оценка критиков, тем выше оценка игроков
# PlayStation и Xbox - давние конкуренты на рынке США, поэтому там платформы этих компаний имеют достаточно схожие продажи в рамках одного поколения консолей
# В Европе несколько иная ситуация - Xbox всегда был нацелен на американскую аудиторию, поэтому некоторые функции были доступны только для них, а в купе с общей политикой компании - становится все еще печальнее. Так, при старте продаж Xbox One, во многих странах Европейского союза эта консоль вовсе не была доступна
# Популярность Nintendo 3DS в Японии обуславливает не только то, что Nintendo - местный производитель, но и то, что на рынке Японии крайне популярны портативные консоли, в которые помимо Nintendo 3DS входит и PlayStation Vita
# В целом, рынки Северной Америки и Европы достаточно сильно похожи, чего не скажешь
# о Японии
# В Японии преобладает жанр RPG, поскольку это тот жанр, который является
# знаковым во всей японской игровой индустрии, существует даже отдельный жанр для
# местных RPG - jRPG (Japan RPG)
# Также стоит отметить, что в Японии игроки отдают предпочтение играм, в которых
# имеется глубокий сюжет и развитая история окружающего мира, в то время как
# американские и европейские игроки отдают предпочтение сессионным играм, когда
# можно уделить игре небольшой промежуток времени, достигнув при этом логического
# завершения партии
# Ключевое различие рынков в том, что японский рынок нацелен на условно детские игры, потому как в этом регионе наиболее распространены портативные консоли, которыми чаще всего пользуются именно дети
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера V2❌</h1>
#
# Вывод хороший. Но нужно оформить его в ячейке маркдаун и проверить на соответствие промежуточным результам.
#
# Например сейчас результат проверки второй гипотезы не соответствует промежуточному выводу.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h1> Комментарий ревьюера✅</h1>
#
# Вторая гипотеза проверена. Все верно.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# Нужно добавить вывод по результатам проверки гипотез.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h1> Комментарий ревьюера ❌</h1>
#
# Общего вывода нет. Добавь пожалуйста вывод по результатам всей работы.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Общий комментарий </h1>
#
# Проект сыроват. В целом видно, что выполнение заданий не вызывает у тебя затруднений. Все рассчеты выполнены верно, ты умело применяешь доступные инструменты. Но аналитическая работа это не только расчеты, но и презентация результатов. Читать проект без структуры довольно сложно.
#
# Есть замечания, которые нужно устранить, прежде чем я приму твою работу.
#
# Что нужно поправить:
# - пояснить почему заполнение пропусков в числовых колонках средним значением допустимо. Какую долю у нас составляют пропуски в этих колонках? При какой доле есть смысл что-то заполнять?
# - пояснить применение целочисленного типа ко всем числовым колонкам.
# - нужно добавить расчеты, по которым можно сделать вывод о выборе актуальных платформ.
# - нужно построить график боксплот без выбросов.
# - при определении самого прибыльного жанра нужно воспользоваться средними или медианными продажами.
# - после оценки коэффициентов корреляции между продажами и оценками добавить вывод.
# - проверить вывод о корреляции на остальных платформах.
# - при построении портретов пользователей учесть игры без рейтинга ESRB.
# - по результатам построения портретов добавить вывод.
# - добавить вывод по результатам проверки гипотез.
# - добавить общий вывод.
# - сформировать структуру проекта, отделить шаги заголовками (обзор, предобработка, анализ, портреты, гипотезы). Каждый шаг завершить коротким выводом.
#
# Крайне желательно оформить построенные графики.
#
# Жду твою работу на повторную проверку.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h1> Общий комментарий V2</h1>
#
# Спасибо за твои доработки.
#
# Тебе удалось устранить многое, но кое-что еще нужно исправить.
#
# Что нужно поправить:
# - поменять типы ячеек, в которых ты пишешь комментарии на markdown.
# - проверить код, не все ячейки работают.
# - нужно добавить таблицу или график, на которых будет видно, что топовые платформы еще не прошли свой пик продаж.
# - нужно добавить вывод после определения самого прибыльного жанра.
# - при построении портретов пользователей учесть игры без рейтинга ESBR.
# - при проведении статистических тестов отфильтровать данные от пропусков и проверить выводы после расчетов.
#
#
# Жду твой проект на следующую итерацию проверки. Если у тебя есть вопросы, не стесняйся из задавать. Если у тебя есть сложности в решении, каких-то заданий ты можешь обратиться к преподавателю по проектам в канале в слаке.
#
#
# </div>
