# %%
import pandas as pd
import numpy as np

data = pd.read_csv('data.csv')
#data
data.describe()

df=data

#df.head(5)

#df.id
f=1

type(f)


df.count()

df.shape

df.sort_values('open_date').head(5)


df[ df['dns'] == 0] .count

#df.corr()


#df['cafe_count'].plot(kind = 'hist', legend = 1, xlim = [0,50])

#df


# df['cafe_count'].plot(kind = 'kde', legend = 1, xlim = [0,50])

#df.groupby('is_moscow')['work_hours'].plot(kind = 'kde', legend = 1, xlim = [0,50])

#df[['cafe_count']]





df.groupby('is_moscow')['finance_count'].plot(kind = 'kde', legend = 1)
# Out:
# is_moscow
# False    AxesSubplot(0.125,0.125;0.775x0.755)
# True     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: finance_count, dtype: object
